# %% [markdown]
# Задача 1.
# Реализовать текстовый калькулятор нескольких правильных, неправильных и смешанных дробей  и обычных чисел с математическим порядком вычисления. Способ записи смешанных дробей – 5(1/4), правильных – 5/9, неправильных 19/7. Результат должен быть сокращен и при необходимости в виде смешанной дроби. После завершения операции позволяет ввести следующее выражение. Завершение работы с программой вызывается при вводе команды exit. Также добавить в калькулятор возможность сохранение результата вычислений по команде ‘save наименование_результата’. Реализовать сохранение до 10 результатов. При вводе команды del наименование_результата удаляет результат из сохраненных. При вводе команды to double, калькулятор выводит результат в виде числа с плавающей точкой. Функцию eval() и его поодобия использовать ЗАПРЕЩЕНО!

# %% [markdown]
# ### Условимся, что деление умножение вычитание сложение соответсвенно : * - +

# %%
def result(exp):
    from fractions import Fraction
    import re
    exp ='0+'+ exp
    for i in range(1, len(exp)-1):
        if exp[i] == '-'  and not(exp[i-1] == '+'or exp[i-1] == '-' or exp[i+1] == '+'or exp[i+1] == '-' or exp[i-1] == ':' or exp[i-1] == '*' ):
            exp = exp[:i] + exp[i] + '.' + exp[i+1:]
    print('Строка на вход',exp)
    # Убираем пробелы между символами в строке 
    exp = exp.replace(' ','')
    sym = ''
    # ---multiplication---
    pattern1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][*:][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][*:][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern3 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][*:][-]?[0-9]{1,}")
    pattern4 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[*:][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern5 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[*:][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern6 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[*:][-]?[0-9]{1,}")
    pattern7 = re.compile(r"[-]?[0-9]{1,}[*:][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern8 = re.compile(r"[-]?[0-9]{1,}[*:][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern9 = re.compile(r"[-]?[0-9]{1,}[*:][-]?[0-9]{1,}")
    for i in range(exp.count('*')+exp.count(':')):
        for i in range(len(exp)):
            h_str = exp[i:]
            exp = exp.replace('--','-.-').replace('+-','+.-')
            if pattern1.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break
            if pattern2.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern3.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern4.match(h_str):  
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break  
            if pattern5.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1           
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2              
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern6.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1              
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern7.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break
            if pattern8.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2          
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern9.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                frac_n1 = Fraction(int(n1))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break



        if sym == ':':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1/frac_n2), 1)
            
        if sym == '*':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1*frac_n2), 1)
        
        print('после умножения',exp)
    exp = exp.replace('-.-','+').replace('+.-','-').replace('-.','-').replace('+.','+')
    # ---addition---
    pattern1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][+-][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][+-][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern3 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)][+-][-]?[0-9]{1,}")
    pattern4 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[+-][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern5 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[+-][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern6 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}[+-][-]?[0-9]{1,}")
    pattern7 = re.compile(r"[-]?[0-9]{1,}[+-][-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
    pattern8 = re.compile(r"[-]?[0-9]{1,}[+-][-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
    pattern9 = re.compile(r"[-]?[0-9]{1,}[+-][-]?[0-9]{1,}")
    for i in range(exp.count('+')+exp.count('-')):
        for i in range(len(exp)):
            h_str = exp[i:]
            if pattern1.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break
            if pattern2.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern3.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                k = n1.count('-')
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(abs(int(n1_lst[1])),abs(int(n1_lst[2]))) + abs(int(n1_lst[0]))
                frac_n1 = ((-1)**(k))*(frac_n1)
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern4.match(h_str):  
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break  
            if pattern5.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1           
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2              
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern6.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1              
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern7.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[(][-+]?[0-9]{1,}[/][-+]?[0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                k = n2.count('-')
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                
                frac_n2 = Fraction(abs(int(n2_lst[1])),abs(int(n2_lst[2]))) + abs(int(n2_lst[0]))
                frac_n2 = ((-1)**(k))*(frac_n2)
                break
            if pattern8.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}[/][-+]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2          
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern9.match(h_str):
                p_n1 = re.compile(r"[-]?[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                frac_n1 = Fraction(int(n1))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[-]?[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break


        if sym == '+':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1+frac_n2), 1)
        if sym == '-':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1-frac_n2), 1)
    return exp


def brackets(primer):
    for k, v in gl_for_sv.items():
        primer = primer.replace(k,v)

    primer = primer.replace(' ','')



    for i in range(1,len(primer)-1):
        if primer[i] == '(' and primer[i-1].isdigit():
            primer = primer[:i] +'<'+primer[i+1:]
            primer = primer[:i] + primer[i:].replace(')','>',1)
    primer = primer.replace('(','[').replace(')',']').replace('<','(').replace('>',')')
    
    
    
    
    print('После скобок',primer )
    for i in range(primer.count('[')):
        for ind1, sym1 in enumerate(primer):
            if sym1 == '[':
                index_l = int(ind1)
            if sym1 == ']':
                index_r = int(ind1)
                srez = primer[index_l:index_r+1]
                res = result(srez[1:-1])
                primer = primer.replace(srez,res)
                break
    primer = result(primer)
    return primer

# %%
gl_res = ''
def click():
    a = txt.get()
    global gl_res
    gl_res = brackets(a)
    res = 'Ответ:{}'.format(gl_res)
    lbl.configure(text = res)

gl_for_sv = {}
def saving():
    global gl_for_sv
    global gl_res
    gl_for_sv[perem.get()] = gl_res

def deleting():
    global gl_for_sv
    del gl_for_sv[perem.get()]

def tochka():
    global gl_res
    lst1 = gl_res.split('/')
    lst1.append('1')
    a = int(lst1[0])/int(lst1[1])
    res = 'Ответ:{}'.format(a)
    lbl.configure(text = res)

def prav():
    global gl_res
    if gl_res[0] == '-':
        
        lst1 = gl_res[1:].split('/')
        b = int(lst1[0])%int(lst1[1])
        a = int(lst1[0])//int(lst1[1])
        res = 'Ответ:{}{}({}/{})'.format(gl_res[0],a,b,int(lst1[1]))
    else:
        lst1 = gl_res.split('/')
        b = int(lst1[0])%int(lst1[1])
        a = int(lst1[0])//int(lst1[1])
        res = 'Ответ:{}({}/{})'.format(a,b,int(lst1[1]))
    lbl.configure(text = res)

def neprav():
    global gl_res
    res = 'Ответ:{}'.format(gl_res)
    lbl.configure(text = res)

from tkinter import *
window = Tk()  
window.title("Калькулятор")  
window.geometry('600x300')
# ---Ввод и получение результата---
txt = Entry(window,width=90)
txt.place(x = 27, y = 50) 
lbll = Label(window,font="Arial 16", text="Введите уравнение:")
lbll.place(x = 200,y = 15 )
lbl = Label(window,font="Arial 20", text="Ответ: ")
lbl.place(x = 22,y = 200 )
btn = Button(window, text="Получить результат",width = 20,height = 5 ,command=click)
btn.place(x = 215, y = 100) 
# ---Сохранение переменных---
lb = Label(window, text="Сохраить/Удалить перем:")
lb.place(x = 380,y = 100 )
perem = Entry(window,width=5)
perem.place(x = 550, y = 100) 
baton = Button(window, text="Сохранить",width = 29,command=saving)
baton.place(x = 380, y = 130) 
# ---Удаление переменных---
delbtn = Button(window, text="Удалить",width = 29,command=deleting)
delbtn.place(x = 380, y = 160) 
# ---Выход из программы---
exbtn = Button(window, text="Выход",width = 20, command=window.destroy)
exbtn.place(x = 440, y = 270) 
# ---Плавающая точка---
plbtn = Button(window, text="С точкой",width = 25,command=tochka)
plbtn.place(x = 20, y = 100) 
# ---Правильная дробь---
pravbtn = Button(window, text='Правильная',width = 25,command=prav)
pravbtn.place(x = 20, y = 130) 
# ---Вернуть назад---
prav1btn = Button(window, text='Не правильная',width = 25,command=neprav)
prav1btn.place(x = 20, y = 160) 
window.mainloop()
# Out:
# После скобок 2-[5-6]
# Строка на вход 0+5-.6
# Строка на вход 0+2--1
# После скобок 2-[5(1/2)-6(1/2)]
# Строка на вход 0+5(1/2)-.6(1/2)
# Строка на вход 0+2--1

# %% [markdown]
# # Trash

# %%
gl_for_sv
# Out:
# {}

# %%
from fractions import Fraction
Fraction(-7,-5)
# Out:
# Fraction(7, 5)

# %%
primer = '((5/6)+3/7+7(6/5)*(5(6/7)+3) + 2)'
    primer = '0+' +primer+ '+0'


    for i in range(1,len(primer)-1):
        if primer[i] == '(' and primer[i-1].isdigit():
            primer = primer[:i] +'<'+primer[i+1:]
            primer = primer[:i] + primer[i:].replace(')','>',1)
    primer = primer.replace('(','[').replace(')',']').replace('<','(').replace('>',')')





print(primer)
# Out:
# 0+[[5/6]+3/7+7(6/5)*[5(6/7)+3]+2]+0

# %%
r = 'kkkkkkkkkkkkkkkkkkkkkkkakkkkkkkkkkkkkkbbbbbbbb' 
r = r[:4] + r[4:].replace('a','c',1)
print(r)
# Out:
# kkkkkkkkkkkkkkkkkkkkkkkckkkkkkkkkkkkkkbbbbbbbb

# %%
'5'+'asd'+'ads'
# Out:
# '5asdads'
