# %% [markdown]
# Задача 1.
# Реализовать текстовый калькулятор нескольких правильных, неправильных и смешанных дробей  и обычных чисел с математическим порядком вычисления. Способ записи смешанных дробей – 5(1/4), правильных – 5/9, неправильных 19/7. Результат должен быть сокращен и при необходимости в виде смешанной дроби. После завершения операции позволяет ввести следующее выражение. Завершение работы с программой вызывается при вводе команды exit. Также добавить в калькулятор возможность сохранение результата вычислений по команде ‘save наименование_результата’. Реализовать сохранение до 10 результатов. При вводе команды del наименование_результата удаляет результат из сохраненных. При вводе команды to double, калькулятор выводит результат в виде числа с плавающей точкой. Функцию eval() и его поодобия использовать ЗАПРЕЩЕНО!

# %% [markdown]
# ### Условимся, что деление умножение вычитание сложение соответсвенно : * - +

# %%
def result(exp):
    from fractions import Fraction
    import re
    # Убираем пробелы между символами в строке 
    exp = exp.replace(' ','')
    # ---multiplication---
    pattern1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}[/][0-9]{1,}")
    pattern3 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}")
    pattern4 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern5 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}[/][0-9]{1,}")
    pattern6 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}")
    pattern7 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern8 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}[/][0-9]{1,}")
    pattern9 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}")
    for i in range(exp.count(':')+exp.count('*')):
        for i in range(len(exp)):
            h_str = exp[i:]
            if pattern1.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern2.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1                
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern3.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1             
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern4.match(h_str):  
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break  
            if pattern5.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1           
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2              
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern6.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1              
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern7.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2             
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern8.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2          
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern9.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                frac_n1 = Fraction(int(n1))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break


        if sym == ':':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1/frac_n2), 1)
            p
        if sym == '*':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1*frac_n2), 1)

    # ---addition---
    pattern1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][+-][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][+-][0-9]{1,}[/][0-9]{1,}")
    pattern3 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][+-][0-9]{1,}")
    pattern4 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[+-][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern5 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[+-][0-9]{1,}[/][0-9]{1,}")
    pattern6 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[+-][0-9]{1,}")
    pattern7 = re.compile(r"[0-9]{1,}[+-][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern8 = re.compile(r"[0-9]{1,}[+-][0-9]{1,}[/][0-9]{1,}")
    pattern9 = re.compile(r"[0-9]{1,}[+-][0-9]{1,}")
    for i in range(exp.count('+')+exp.count('-')):
        for i in range(len(exp)):
            h_str = exp[i:]
            if pattern1.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern2.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1                
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern3.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1             
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern4.match(h_str):  
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break  
            if pattern5.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1           
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2              
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern6.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1              
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern7.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2             
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern8.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2          
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern9.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                frac_n1 = Fraction(int(n1))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break


        if sym == '+':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1+frac_n2), 1)
            p
        if sym == '-':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1-frac_n2), 1)
    print(exp)
result('7/3 + 5/6 * 7(8/9) : 35/7 - 48/9')
# Out:
# -91/54

# %% [markdown]
# # Trash

# %%
a = Fraction(3, 10)
print(str(a).replace('2','3p'))
# Out:
# 3/10

# %%
import re
p = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
print(p.match('20(1/3)*5(2/3) khhv jhvjhv jhvjhv 21(1/3)*5(2/3)'))
# Out:
# <re.Match object; span=(0, 14), match='20(1/3)*5(2/3)'>

# %%
'sdf'[1:]
# Out:
# 'df'

# %%
n1 = '512'

n2_copy = n2
frac_n1 = Fraction(int(n1))
print(frac_n1)
# Out:
# 512

# %%
def result(exp):
    from fractions import Fraction
    import re
    # Убираем пробелы между символами в строке 
    exp = exp.replace(' ','')
    # ---multiplication---
    pattern1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}[/][0-9]{1,}")
    pattern3 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)][*:][0-9]{1,}")
    pattern4 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern5 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}[/][0-9]{1,}")
    pattern6 = re.compile(r"[0-9]{1,}[/][0-9]{1,}[*:][0-9]{1,}")
    pattern7 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
    pattern8 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}[/][0-9]{1,}")
    pattern9 = re.compile(r"[0-9]{1,}[*:][0-9]{1,}")
    for i in range(exp.count(':')+exp.count('*')):
        for i in range(len(exp)-1):
            h_str = exp[i:]
            if pattern1.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)    
                
                n1_copy = n1
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern2.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1                
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern3.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1             
                n1 = n1.replace('/',' ').replace(')',' ').replace('(',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0])*int(n1_lst[2]) + int(n1_lst[1]), int(n1_lst[2]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern4.match(h_str):  
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break  
            if pattern5.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1           
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)
                
                n2_copy = n2              
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern6.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1              
                n1 = n1.replace('/',' ')
                n1_lst = n1.split()
                frac_n1 = Fraction(int(n1_lst[0]), int(n1_lst[1]))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break
            if pattern7.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[(][0-9]{1,}[/][0-9]{1,}[)]")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2             
                n2 = n2.replace('/',' ').replace(')',' ').replace('(',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0])*int(n2_lst[2]) + int(n2_lst[1]), int(n2_lst[2]))
                
                break
            if pattern8.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)

                n1_copy = n1
                frac_n1 = Fraction(int(n1))

                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}[/][0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2          
                n2 = n2.replace('/',' ')
                n2_lst = n2.split()
                frac_n2 = Fraction(int(n2_lst[0]), int(n2_lst[1]))
                
                break
            if pattern9.match(h_str):
                p_n1 = re.compile(r"[0-9]{1,}")
                n1 = p_n1.match(h_str).group(0)
                h_str = h_str.replace(n1, '', 1)
                
                n1_copy = n1
                frac_n1 = Fraction(int(n1))
                
                sym = h_str[0]
                h_str = h_str[1:]
                p_n2 = re.compile(r"[0-9]{1,}")
                n2 = p_n2.match(h_str).group(0)

                n2_copy = n2
                frac_n2 = Fraction(int(n2))
                break


        if sym == ':':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1/frac_n2), 1)
            p
        if sym == '*':
            exp = exp.replace(str(n1_copy)+str(sym)+str(n2_copy),str(frac_n1*frac_n2), 1)
    print(exp)
    # ---addition---

result('56(34/4):8*10/9 ')
result('5*3/6*7')
